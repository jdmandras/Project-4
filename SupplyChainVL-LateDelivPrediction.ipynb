# %%
# Import the modules
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import GridSearchCV

# %%
#load csv file into dataframe DataCoSupplyChainDataset_VL.csv from Resources folder
file_path = Path("Resources/DataCoSupplyChainDataset_VL.csv")
sales_df = pd.read_csv(file_path)
sales_df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#     Delivery Status  Late_delivery_risk   Category Name Customer City  \
# 0  Advance shipping                   0  Sporting Goods        Caguas
# 1     Late delivery                   1  Sporting Goods        Caguas
# 2  Shipping on time                   0  Sporting Goods      San Jose
# 3  Advance shipping                   0  Sporting Goods   Los Angeles
# 4  Advance shipping                   0  Sporting Goods        Caguas
#
#   Customer Country  Customer Id Customer Segment  ...      Order State  \
# 0      Puerto Rico        20755         Consumer  ...  Java Occidental
# 1      Puerto Rico        19492         Consumer  ...         Rajastán
# 2          EE. UU.        19491         Consumer  ...         Rajastán
# 3          EE. UU.        19490      Home Office  ...       Queensland
# 4      Puerto Rico        19489        Corporate  ...       Queensland
#
#       Order Status  Order Zipcode Product Card Id  Product Category Id  \
# 0         COMPLETE            NaN            1360                   73
# 1          PENDING            NaN            1360                   73
# 2           CLOSED            NaN            1360                   73
# 3         COMPLETE            NaN            1360                   73
# 4  PENDING_PAYMENT            NaN            1360                   73
#
#    Product Name Product Price shipping date (DateOrders)   Shipping Mode  \
# 0  Smart watch         327.75             2/3/2018 22:56  Standard Class
# 1  Smart watch         327.75            1/18/2018 12:27  Standard Class
# 2  Smart watch         327.75            1/17/2018 12:06  Standard Class
# 3  Smart watch         327.75            1/16/2018 11:45  Standard Class
# 4  Smart watch         327.75            1/15/2018 11:24  Standard Class
#
#    order_date_VL
# 0     2018-01-31
# 1     2018-01-13
# 2     2018-01-13
# 3     2018-01-13
# 4     2018-01-13
#
# [5 rows x 43 columns]

# %%
sales_df.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Delivery Status', 'Late_delivery_risk', 'Category Name',
#        'Customer City', 'Customer Country', 'Customer Id', 'Customer Segment',
#        'Customer State', 'Customer Zipcode', 'Department Id',
#        'Department Name', 'Latitude', 'Longitude', 'Market', 'Order City',
#        'Order Country', 'Order Customer Id', 'order date (DateOrders)',
#        'Order Id', 'Order Item Cardprod Id', 'Order Item Discount',
#        'Order Item Discount Rate', 'Order Item Id', 'Order Item Product Price',
#        'Order Item Profit Ratio', 'Order Item Quantity', 'Sales',
#        'Order Item Total', 'Order Profit Per Order', 'Order Region',
#        'Order State', 'Order Status', 'Order Zipcode', 'Product Card Id',
#        'Product Category Id', 'Product Name', 'Product Price',
#        'shipping date (DateOrders)', 'Shipping Mode', 'order_date_VL'],
#       dtype='object')

# %% [markdown]
# Unique Order dataframe preparation

# %%
#remove rows with "Delivery Status"="Shipping canceled"
sales_df = sales_df[sales_df["Delivery Status"] != "Shipping canceled"]

# %%
# create a new dataframe orders_df listing all unique "Order ID" as index with min "Type", "Days for shipment (scheduled)"
orders_df = sales_df.groupby("Order Id").agg({"Type": "min", "Days for shipment (scheduled)": "min"})
#add columns to orders_df from sales_df with 'Customer Segment', 'Department Id', 'Order Country'
orders_df = orders_df.join(sales_df.groupby("Order Id").agg({"Customer Segment": "min","Market":"min", "Order Country": "min", "Order State":"min",
                                                             "Shipping Mode":"min", "Late_delivery_risk":"min","Order Region":"min",
                                                             "Order Status":"min"}))
#add columns to orders_df from sales_df with sum of "Order Item Product Price", "Order Item Discount", 'Order Item Quantity',"Order Item Total"
orders_df = orders_df.join(sales_df.groupby("Order Id").agg({"Order Item Product Price": "sum", "Order Item Discount": "sum", "Order Item Quantity": "sum", "Order Item Total": "sum"}))
# add column with number of unique "Product Card Id" per "Order Id"
orders_df["Number of Products"] = sales_df.groupby("Order Id")["Product Card Id"].nunique()
#add column with number of unique "Category Name" per "Order Id"
orders_df["Number of Categories"] = sales_df.groupby("Order Id")["Category Name"].nunique()
#add column with number of unique "Department Name" per "Order Id"
orders_df["Number of Departments"] = sales_df.groupby("Order Id")["Department Name"].nunique()
orders_df.tail()
# Out:
#               Type  Days for shipment (scheduled) Customer Segment  \
# Order Id
# 77200     TRANSFER                              4         Consumer
# 77201        DEBIT                              4         Consumer
# 77202        DEBIT                              4         Consumer
# 77203      PAYMENT                              4        Corporate
# 77204         CASH                              0        Corporate
#
#                 Market Order Country      Order State   Shipping Mode  \
# Order Id
# 77200     Pacific Asia     Indonesia  Java Occidental  Standard Class
# 77201     Pacific Asia     Indonesia  Java Occidental  Standard Class
# 77202     Pacific Asia     Indonesia  Java Occidental  Standard Class
# 77203     Pacific Asia     Indonesia  Java Occidental  Standard Class
# 77204     Pacific Asia     Australia       Queensland        Same Day
#
#           Late_delivery_risk    Order Region     Order Status  \
# Order Id
# 77200                      1  Southeast Asia       PROCESSING
# 77201                      0  Southeast Asia         COMPLETE
# 77202                      0  Southeast Asia         COMPLETE
# 77203                      0  Southeast Asia  PENDING_PAYMENT
# 77204                      1         Oceania           CLOSED
#
#           Order Item Product Price  Order Item Discount  Order Item Quantity  \
# Order Id
# 77200                   215.820007            53.959999                    1
# 77201                   215.820007            43.160000                    1
# 77202                   327.750000            13.110000                    1
# 77203                    11.540000             0.630000                    1
# 77204                    39.750000             4.770000                    1
#
#           Order Item Total  Number of Products  Number of Categories  \
# Order Id
# 77200           161.869995                   1                     1
# 77201           172.660004                   1                     1
# 77202           314.640015                   1                     1
# 77203            10.910000                   1                     1
# 77204            34.980000                   1                     1
#
#           Number of Departments
# Order Id
# 77200                         1
# 77201                         1
# 77202                         1
# 77203                         1
# 77204                         1

# %%
orders_df.columns
# Out:
# Index(['Type', 'Days for shipment (scheduled)', 'Customer Segment', 'Market',
#        'Order Country', 'Order State', 'Shipping Mode', 'Late_delivery_risk',
#        'Order Region', 'Order Status', 'Order Item Product Price',
#        'Order Item Discount', 'Order Item Quantity', 'Order Item Total',
#        'Number of Products', 'Number of Categories', 'Number of Departments'],
#       dtype='object')

# %%
#change column name "Order Item Total" to "order_total", change column "Order Item Product Price" to "order_original_price", "Order Item Discount" to "order_discount", "Order Item Quantity" to "no_of_items"
orders_df = orders_df.rename(columns={"Order Item Total": "order_total", "Order Item Product Price": "order_original_price", 
                                      "Order Item Discount": "order_discount", "Order Item Quantity": "no_of_items",
                                      "Number of Products": "no_of_unique_items", "Number of Categories": "no_of_unique_categories","Number of Departments": "no_of_unique_departments"})

# %%
#show order id ="49405"
orders_df.loc[orders_df.index == 68703]
# Out:
#            Type  Days for shipment (scheduled) Customer Segment  Market  \
# Order Id
# 68703     DEBIT                              4         Consumer  Europe
#
#          Order Country Order State   Shipping Mode  Late_delivery_risk  \
# Order Id
# 68703      Reino Unido  Inglaterra  Standard Class                   0
#
#              Order Region Order Status  order_original_price  order_discount  \
# Order Id
# 68703     Northern Europe     COMPLETE           3089.949993           681.5
#
#           no_of_items  order_total  no_of_unique_items  \
# Order Id
# 68703              13  2768.409988                   5
#
#           no_of_unique_categories  no_of_unique_departments
# Order Id
# 68703                           5                         3

# %%
#save orders_df to csv file
orders_df.to_csv("Resources/orders_df.csv")

# %% [markdown]
# DATA CLEANING

# %%
#show data type for each column
orders_df.dtypes
# Out:
# Type                              object
# Days for shipment (scheduled)      int64
# Customer Segment                  object
# Market                            object
# Order Country                     object
# Order State                       object
# Shipping Mode                     object
# Late_delivery_risk                 int64
# Order Region                      object
# Order Status                      object
# order_original_price             float64
# order_discount                   float64
# no_of_items                        int64
# order_total                      float64
# no_of_unique_items                 int64
# no_of_unique_categories            int64
# no_of_unique_departments           int64
# dtype: object

# %%
#dummy code categorical columns
orders_df = pd.get_dummies(orders_df, columns=["Type", "Customer Segment", "Order Country", "Order State", "Shipping Mode", "Market", "Order Region", "Order Status"])
orders_df.head()
# Out:
#           Days for shipment (scheduled)  Late_delivery_risk  \
# Order Id
# 1                                     4                   0
# 2                                     4                   0
# 4                                     4                   1
# 5                                     4                   1
# 7                                     2                   1
#
#           order_original_price  order_discount  no_of_items  order_total  \
# Order Id
# 1                   299.980011       60.000000            1   239.979996
# 2                   379.980011       50.600000            7   529.380005
# 4                   184.960001       78.980000           14   620.870014
# 5                   839.920029      142.789999           10   987.070007
# 7                   515.960016       54.400000            7   525.520004
#
#           no_of_unique_items  no_of_unique_categories  \
# Order Id
# 1                          1                        1
# 2                          3                        3
# 4                          4                        4
# 5                          4                        4
# 7                          3                        3
#
#           no_of_unique_departments  Type_CASH  ...  Order Region_West Asia  \
# Order Id                                       ...
# 1                                1       True  ...                   False
# 2                                3      False  ...                   False
# 4                                4       True  ...                   False
# 5                                2      False  ...                   False
# 7                                2      False  ...                   False
#
#           Order Region_West of USA   Order Region_Western Europe  \
# Order Id
# 1                             False                        False
# 2                             False                        False
# 4                             False                        False
# 5                             False                        False
# 7                             False                        False
#
#           Order Status_CLOSED  Order Status_COMPLETE  Order Status_ON_HOLD  \
# Order Id
# 1                        True                  False                 False
# 2                       False                  False                 False
# 4                        True                  False                 False
# 5                       False                   True                 False
# 7                       False                   True                 False
#
#           Order Status_PAYMENT_REVIEW  Order Status_PENDING  \
# Order Id
# 1                               False                 False
# 2                               False                 False
# 4                               False                 False
# 5                               False                 False
# 7                               False                 False
#
#           Order Status_PENDING_PAYMENT  Order Status_PROCESSING
# Order Id
# 1                                False                    False
# 2                                 True                    False
# 4                                False                    False
# 5                                False                    False
# 7                                False                    False
#
# [5 rows x 1302 columns]

# %%
#show basic statistics for the dataframe
orders_df.describe()
# Out:
#        Days for shipment (scheduled)  Late_delivery_risk  \
# count                   62897.000000        62897.000000
# mean                        2.935625            0.573127
# std                         1.373760            0.494627
# min                         0.000000            0.000000
# 25%                         2.000000            0.000000
# 50%                         4.000000            1.000000
# 75%                         4.000000            1.000000
# max                         4.000000            1.000000
#
#        order_original_price  order_discount   no_of_items   order_total  \
# count          62897.000000    62897.000000  62897.000000  62897.000000
# mean             388.062967       56.756416      5.844333    503.118830
# std              288.728212       46.618533      4.170329    321.290779
# min                9.990000        0.000000      1.000000      7.490000
# 25%              159.980000       20.000000      2.000000    244.349998
# 50%              339.970013       47.400000      5.000000    456.869995
# 75%              547.960016       82.480000      9.000000    721.960007
# max             3089.949993      681.500000     24.000000   2768.409988
#
#        no_of_unique_items  no_of_unique_categories  no_of_unique_departments
# count        62897.000000             62897.000000              62897.000000
# mean             2.431006                 2.426666                  2.002560
# std              1.258391                 1.254526                  0.935946
# min              1.000000                 1.000000                  1.000000
# 25%              1.000000                 1.000000                  1.000000
# 50%              2.000000                 2.000000                  2.000000
# 75%              3.000000                 3.000000                  3.000000
# max              5.000000                 5.000000                  5.000000

# %%
# change column name Late_delivery_risk to late_delivery
orders_df = orders_df.rename(columns={"Late_delivery_risk": "late_delivery"})
#show the number of orders in each delivery time bucket
orders_df["late_delivery"].value_counts()
# Out:
# late_delivery
# 1    36048
# 0    26849
# Name: count, dtype: int64

# %% [markdown]
# LOGISTIC REGRESSION - DELIVERY TIME PREDICTION MODEL

# %%
# Separate the data into labels and features
# Separate the y variable, the labels
y = orders_df["late_delivery"]

# Separate the X variable, the features
X = orders_df.drop(columns="late_delivery")

# %%
# Review the y variable Series
print(f"Labels: {y[:10]}")
# Out:
# Labels: Order Id
# 1     0
# 2     0
# 4     1
# 5     1
# 7     1
# 8     0
# 9     1
# 10    1
# 11    0
# 12    0
# Name: late_delivery, dtype: int64

# %%
# Review the X variable DataFrame
print(f"Data: {X[:10]}")
# Out:
# Data:           Days for shipment (scheduled)  order_original_price  order_discount  \
# Order Id
# 1                                     4            299.980011       60.000000
# 2                                     4            379.980011       50.600000
# 4                                     4            184.960001       78.980000
# 5                                     4            839.920029      142.789999
# 7                                     2            515.960016       54.400000
# 8                                     4            219.960003      142.070000
# 9                                     4            499.970009       12.000000
# 10                                    4            601.940016      126.150000
# 11                                    4            299.930000       72.990000
# 12                                    4            524.950008      103.490000
#
#           no_of_items  order_total  no_of_unique_items  \
# Order Id
# 1                   1   239.979996                   1
# 2                   7   529.380005                   3
# 4                  14   620.870014                   4
# 5                  10   987.070007                   4
# 7                   7   525.520004                   3
# 8                  13   587.770004                   3
# 9                   4   587.960007                   2
# 10                  6   525.770010                   4
# 11                 15   846.800003                   4
# 12                 18  1196.380005                   5
#
#           no_of_unique_categories  no_of_unique_departments  Type_CASH  \
# Order Id
# 1                               1                         1       True
# 2                               3                         3      False
# 4                               4                         4       True
# 5                               4                         2      False
# 7                               3                         2      False
# 8                               3                         3      False
# 9                               2                         2      False
# 10                              4                         3      False
# 11                              4                         4      False
# 12                              5                         4       True
#
#           Type_DEBIT  ...  Order Region_West Asia  Order Region_West of USA   \
# Order Id              ...
# 1              False  ...                   False                      False
# 2              False  ...                   False                      False
# 4              False  ...                   False                      False
# 5               True  ...                   False                      False
# 7               True  ...                   False                      False
# 8              False  ...                   False                      False
# 9              False  ...                   False                      False
# 10             False  ...                   False                      False
# 11             False  ...                   False                      False
# 12             False  ...                   False                      False
#
#           Order Region_Western Europe  Order Status_CLOSED  \
# Order Id
# 1                               False                 True
# 2                               False                False
# 4                               False                 True
# 5                               False                False
# 7                               False                False
# 8                               False                False
# 9                               False                False
# 10                              False                False
# 11                              False                False
# 12                              False                 True
#
#           Order Status_COMPLETE  Order Status_ON_HOLD  \
# Order Id
# 1                         False                 False
# 2                         False                 False
# 4                         False                 False
# 5                          True                 False
# 7                          True                 False
# 8                         False                 False
# 9                         False                 False
# 10                        False                 False
# 11                        False                 False
# 12                        False                 False
#
#           Order Status_PAYMENT_REVIEW  Order Status_PENDING  \
# Order Id
# 1                               False                 False
# 2                               False                 False
# 4                               False                 False
# 5                               False                 False
# 7                               False                 False
# 8                               False                 False
# 9                               False                 False
# 10                              False                 False
# 11                               True                 False
# 12                              False                 False
#
#           Order Status_PENDING_PAYMENT  Order Status_PROCESSING
# Order Id
# 1                                False                    False
# 2                                 True                    False
# 4                                False                    False
# 5                                False                    False
# 7                                False                    False
# 8                                False                     True
# 9                                 True                    False
# 10                                True                    False
# 11                               False                    False
# 12                               False                    False
#
# [10 rows x 1301 columns]

# %%
# Import the train_test_learn module
from sklearn.model_selection import train_test_split

# Split the data using train_test_split
# Assign a random_state of 1 to the function
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)
X_train.shape
# Out:
# (47172, 1301)

# %%
X_test.shape
# Out:
# (15725, 1301)

# %%
#concatenate our training data back together
train_data = pd.concat([X_train, y_train], axis=1)

# %%
#Create a logistic regression model
# Import the LogisticRegression module from SKLearn
from sklearn.linear_model import LogisticRegression

# Instantiate the Logistic Regression model with class weight to handle imbalance in the dataset
classifier = LogisticRegression(max_iter=10000)


# Fit the model using scaled training data
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
from sklearn.calibration import CalibratedClassifierCV

# Instantiate the calibrated classifier with sigmoid calibration
calibrated_clf = CalibratedClassifierCV(classifier, method='sigmoid', cv='prefit')

# Fit the calibrated classifier using the validation data (you might need to split your data again)
calibrated_clf.fit(X_train, y_train)
# Out:
# CalibratedClassifierCV(cv='prefit',
#                        estimator=LogisticRegression(max_iter=10000))

# %%
# Get calibrated probabilities
calibrated_probs = calibrated_clf.predict_proba(X_test)

# Predict labels (if needed)
calibrated_preds = calibrated_clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, log_loss

print("Accuracy: ", accuracy_score(y_test, calibrated_preds))
print("Log loss: ", log_loss(y_test, calibrated_probs))
# Out:
# Accuracy:  0.6927821939586646
# Log loss:  0.5414004367066779

# %%
# Make a prediction using the testing data with the calibrated classifier
calibrated_predictions = calibrated_clf.predict(X_test)

pd.DataFrame({"Prediction": calibrated_predictions, "Actual": y_test})
# Out:
#           Prediction  Actual
# Order Id
# 2658               1       1
# 21959              0       1
# 77119              0       1
# 6286               1       0
# 2450               0       1
# ...              ...     ...
# 14644              1       1
# 8832               0       0
# 5990               1       1
# 76735              0       1
# 7836               0       0
#
# [15725 rows x 2 columns]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# Generate a confusion matrix for the model
confusion_matrix(y_test, calibrated_predictions)
# Out:
# array([[5855,  858],
#        [3973, 5039]], dtype=int64)

# %%
# Calculating the confusion matrix
cm = confusion_matrix(y_test, calibrated_predictions)
cm_df = pd.DataFrame(
    cm, index=["Actual On Time [0]", "Actual Late [1]"], columns=["Predicted On Time [0]", "Predicted Late [1]"]
)

# Calculating the accuracy score
acc_score = accuracy_score(y_test, calibrated_predictions)

# Display results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, calibrated_predictions))
# Out:
# Confusion Matrix
#                     Predicted On Time [0]  Predicted Late [1]
# Actual On Time [0]                   5855                 858
# Actual Late [1]                      3973                5039
# Accuracy Score : 0.6927821939586646
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.60      0.87      0.71      6713
#            1       0.85      0.56      0.68      9012
#
#     accuracy                           0.69     15725
#    macro avg       0.73      0.72      0.69     15725
# weighted avg       0.74      0.69      0.69     15725

# %% [markdown]
# Trying to imporve the accuracy score by training the model on more detailed individual product order infromation

# %%
#load csv file into dataframe DataCoSupplyChainDataset_VL.csv from Resources folder
file_path = Path("Resources/DataCoSupplyChainDataset_VL.csv")
sales_df = pd.read_csv(file_path)
sales_df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#     Delivery Status  Late_delivery_risk   Category Name Customer City  \
# 0  Advance shipping                   0  Sporting Goods        Caguas
# 1     Late delivery                   1  Sporting Goods        Caguas
# 2  Shipping on time                   0  Sporting Goods      San Jose
# 3  Advance shipping                   0  Sporting Goods   Los Angeles
# 4  Advance shipping                   0  Sporting Goods        Caguas
#
#   Customer Country  Customer Id Customer Segment  ...      Order State  \
# 0      Puerto Rico        20755         Consumer  ...  Java Occidental
# 1      Puerto Rico        19492         Consumer  ...         Rajastán
# 2          EE. UU.        19491         Consumer  ...         Rajastán
# 3          EE. UU.        19490      Home Office  ...       Queensland
# 4      Puerto Rico        19489        Corporate  ...       Queensland
#
#       Order Status  Order Zipcode Product Card Id  Product Category Id  \
# 0         COMPLETE            NaN            1360                   73
# 1          PENDING            NaN            1360                   73
# 2           CLOSED            NaN            1360                   73
# 3         COMPLETE            NaN            1360                   73
# 4  PENDING_PAYMENT            NaN            1360                   73
#
#    Product Name Product Price shipping date (DateOrders)   Shipping Mode  \
# 0  Smart watch         327.75             2/3/2018 22:56  Standard Class
# 1  Smart watch         327.75            1/18/2018 12:27  Standard Class
# 2  Smart watch         327.75            1/17/2018 12:06  Standard Class
# 3  Smart watch         327.75            1/16/2018 11:45  Standard Class
# 4  Smart watch         327.75            1/15/2018 11:24  Standard Class
#
#    order_date_VL
# 0     2018-01-31
# 1     2018-01-13
# 2     2018-01-13
# 3     2018-01-13
# 4     2018-01-13
#
# [5 rows x 43 columns]

# %%
#drop rows with "Delivery Status"="Shipping canceled"
sales_df = sales_df[sales_df["Delivery Status"] != "Shipping canceled"]

# %%
#drop column "Delivery Status" & "Days for shipment (real)"
sales_df = sales_df.drop(columns=["Delivery Status", "Days for shipping (real)"])

# %%
sales_df.dtypes
# Out:
# Type                              object
# Days for shipment (scheduled)      int64
# Late_delivery_risk                 int64
# Category Name                     object
# Customer City                     object
# Customer Country                  object
# Customer Id                        int64
# Customer Segment                  object
# Customer State                    object
# Customer Zipcode                 float64
# Department Id                      int64
# Department Name                   object
# Latitude                         float64
# Longitude                        float64
# Market                            object
# Order City                        object
# Order Country                     object
# Order Customer Id                  int64
# order date (DateOrders)           object
# Order Id                           int64
# Order Item Cardprod Id             int64
# Order Item Discount              float64
# Order Item Discount Rate         float64
# Order Item Id                      int64
# Order Item Product Price         float64
# Order Item Profit Ratio          float64
# Order Item Quantity                int64
# Sales                            float64
# Order Item Total                 float64
# Order Profit Per Order           float64
# Order Region                      object
# Order State                       object
# Order Status                      object
# Order Zipcode                    float64
# Product Card Id                    int64
# Product Category Id                int64
# Product Name                      object
# Product Price                    float64
# shipping date (DateOrders)        object
# Shipping Mode                     object
# order_date_VL                     object
# dtype: object

# %%
#drrop columns shipping date (DateOrders), order date (DateOrders)   
sales_df = sales_df.drop(columns=["order date (DateOrders)", "shipping date (DateOrders)","Product Name","order_date_VL"])

# %%
#dummy code categorical columns
sales_df = pd.get_dummies(sales_df, columns=["Type", "Category Name", "Customer City","Customer Country",
                                             "Customer Segment", "Customer State", "Department Name","Order Country", "Order State", 
                                             "Shipping Mode", "Market","Order City", "Order Region", "Order Status"])
sales_df.head()
# Out:
#    Days for shipment (scheduled)  Late_delivery_risk  Customer Id  \
# 0                              4                   0        20755
# 1                              4                   1        19492
# 2                              4                   0        19491
# 3                              4                   0        19490
# 4                              4                   0        19489
#
#    Customer Zipcode  Department Id   Latitude   Longitude  Order Customer Id  \
# 0             725.0              2  18.251453  -66.037056              20755
# 1             725.0              2  18.279451  -66.037064              19492
# 2           95125.0              2  37.292233 -121.881279              19491
# 3           90027.0              2  34.125946 -118.291016              19490
# 4             725.0              2  18.253769  -66.037048              19489
#
#    Order Id  Order Item Cardprod Id  ...  Order Region_West Asia  \
# 0     77202                    1360  ...                   False
# 1     75939                    1360  ...                   False
# 2     75938                    1360  ...                   False
# 3     75937                    1360  ...                   False
# 4     75936                    1360  ...                   False
#
#    Order Region_West of USA   Order Region_Western Europe  \
# 0                      False                        False
# 1                      False                        False
# 2                      False                        False
# 3                      False                        False
# 4                      False                        False
#
#    Order Status_CLOSED  Order Status_COMPLETE  Order Status_ON_HOLD  \
# 0                False                   True                 False
# 1                False                  False                 False
# 2                 True                  False                 False
# 3                False                   True                 False
# 4                False                  False                 False
#
#    Order Status_PAYMENT_REVIEW  Order Status_PENDING  \
# 0                        False                 False
# 1                        False                  True
# 2                        False                 False
# 3                        False                 False
# 4                        False                 False
#
#    Order Status_PENDING_PAYMENT  Order Status_PROCESSING
# 0                         False                    False
# 1                         False                    False
# 2                         False                    False
# 3                         False                    False
# 4                          True                    False
#
# [5 rows x 5573 columns]

# %%
#replace Nan with 0
sales_df = sales_df.fillna(0)

# %%
sales_df.describe()
# Out:
#        Days for shipment (scheduled)  Late_delivery_risk    Customer Id  \
# count                  172765.000000       172765.000000  172765.000000
# mean                        2.933100            0.572900    6687.759048
# std                         1.373405            0.494659    4165.069180
# min                         0.000000            0.000000       1.000000
# 25%                         2.000000            0.000000    3252.000000
# 50%                         4.000000            1.000000    6457.000000
# 75%                         4.000000            1.000000    9782.000000
# max                         4.000000            1.000000   20757.000000
#
#        Customer Zipcode  Department Id       Latitude      Longitude  \
# count     172765.000000  172765.000000  172765.000000  172765.000000
# mean       35930.988910       5.444095      29.724145     -84.912610
# std        37537.246337       1.629248       9.811816      21.410511
# min            0.000000       2.000000     -33.937553    -158.025986
# 25%          725.000000       4.000000      18.265436     -98.443069
# 50%        19380.000000       5.000000      33.144863     -76.847908
# 75%        78207.000000       7.000000      39.279617     -66.370583
# max        99205.000000      12.000000      48.781933     115.263077
#
#        Order Customer Id       Order Id  Order Item Cardprod Id  ...  \
# count      172765.000000  172765.000000           172765.000000  ...
# mean         6687.759048   36215.167210              692.618858  ...
# std          4165.069180   21036.193887              336.471170  ...
# min             1.000000       1.000000               19.000000  ...
# 25%          3252.000000   18069.000000              403.000000  ...
# 50%          6457.000000   36126.000000              627.000000  ...
# 75%          9782.000000   54111.000000             1004.000000  ...
# max         20757.000000   77204.000000             1363.000000  ...
#
#        Order Item Product Price  Order Item Profit Ratio  Order Item Quantity  \
# count             172765.000000            172765.000000        172765.000000
# mean                 141.278595                 0.120801             2.127694
# std                  139.862956                 0.466610             1.453663
# min                    9.990000                -2.750000             1.000000
# 25%                   50.000000                 0.080000             1.000000
# 50%                   59.990002                 0.270000             1.000000
# 75%                  199.990005                 0.360000             3.000000
# max                 1999.989990                 0.500000             5.000000
#
#                Sales  Order Item Total  Order Profit Per Order  Order Zipcode  \
# count  172765.000000     172765.000000           172765.000000  172765.000000
# mean      203.828493        183.165948               22.032360    7597.117813
# std       132.392520        120.141871              104.355313   22415.287313
# min         9.990000          7.490000            -4274.979980       0.000000
# 25%       119.980003        104.379997                7.030000       0.000000
# 50%       199.919998        163.990005               31.520000       0.000000
# 75%       299.950012        247.399994               64.800003       0.000000
# max      1999.989990       1939.989990              911.799988   99301.000000
#
#        Product Card Id  Product Category Id  Product Price
# count    172765.000000        172765.000000  172765.000000
# mean        692.618858            31.856065     141.278595
# std         336.471170            15.642216     139.862956
# min          19.000000             2.000000       9.990000
# 25%         403.000000            18.000000      50.000000
# 50%         627.000000            29.000000      59.990002
# 75%        1004.000000            45.000000     199.990005
# max        1363.000000            76.000000    1999.989990
#
# [8 rows x 23 columns]

# %%
# Separate the data into labels and features
# Separate the y variable, the labels
y = sales_df["Late_delivery_risk"]

# Separate the X variable, the features
X = sales_df.drop(columns="Late_delivery_risk")

# %%
# Import the train_test_learn module
from sklearn.model_selection import train_test_split

# Split the data using train_test_split
# Assign a random_state of 1 to the function
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)
X_train.shape
# Out:
# (129573, 5572)

# %%
y_train.shape
# Out:
# (129573,)

# %%
#concatenate our training data back together
train_data = pd.concat([X_train, y_train], axis=1)

# %%
# Import the LogisticRegression module from SKLearn
from sklearn.linear_model import LogisticRegression

# Instantiate the Logistic Regression model
classifier = LogisticRegression(max_iter=10000)

# Fit the model using scaled training data
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
from sklearn.calibration import CalibratedClassifierCV

# Instantiate the calibrated classifier with sigmoid calibration
calibrated_clf = CalibratedClassifierCV(classifier, method='sigmoid', cv='prefit')

# Fit the calibrated classifier using the validation data (you might need to split your data again)
calibrated_clf.fit(X_train, y_train)

# Get calibrated probabilities
calibrated_probs = calibrated_clf.predict_proba(X_test)

# Predict labels (if needed)
calibrated_preds = calibrated_clf.predict(X_test)

# %%
# Make a prediction using the testing data
predictions = classifier.predict(X_test)

pd.DataFrame({"Prediction": predictions, "Actual": y_test})
# Out:
#         Prediction  Actual
# 46463            0       0
# 153114           1       1
# 179302           1       1
# 127823           0       0
# 106978           1       1
# ...            ...     ...
# 53595            0       0
# 78304            0       1
# 168391           1       1
# 149009           0       1
# 78894            0       1
#
# [43192 rows x 2 columns]

# %%
# Calculating the confusion matrix
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
    cm, index=["Actual On-Time Delivery", "Actual Late Delivery"], columns=["Predicted On-Time Delivery", "Predicted Late Delivery"]
)
display(cm_df)
# Print the classification report for the model
target_names = ["On-Time Delivery", "Late Delivery"]
print(classification_report(y_test, predictions, target_names=target_names))
reg_acc_score = accuracy_score(y_test, predictions)
print(f"Accuracy Score: {reg_acc_score}")
# Out:
#                          Predicted On-Time Delivery  Predicted Late Delivery
# Actual On-Time Delivery                       15328                     3119
# Actual Late Delivery                          10054                    14691
#                   precision    recall  f1-score   support
#
# On-Time Delivery       0.60      0.83      0.70     18447
#    Late Delivery       0.82      0.59      0.69     24745
#
#         accuracy                           0.70     43192
#        macro avg       0.71      0.71      0.69     43192
#     weighted avg       0.73      0.70      0.69     43192
#
# Accuracy Score: 0.6950129653639563
