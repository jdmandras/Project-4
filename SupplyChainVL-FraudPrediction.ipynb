# %%
#pip install imbalanced-learn before running the code - used for balancing the set in the later [random forest] part of the code
# pip install xgboost before running the code - used for the xgboost model
# Import the modules
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import GridSearchCV

# %%
#load csv file into dataframe DataCoSupplyChainDataset_VL.csv from Resources folder
file_path = Path("Resources/DataCoSupplyChainDataset_VL.csv")
sales_df = pd.read_csv(file_path)
sales_df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#     Delivery Status  Late_delivery_risk   Category Name Customer City  \
# 0  Advance shipping                   0  Sporting Goods        Caguas
# 1     Late delivery                   1  Sporting Goods        Caguas
# 2  Shipping on time                   0  Sporting Goods      San Jose
# 3  Advance shipping                   0  Sporting Goods   Los Angeles
# 4  Advance shipping                   0  Sporting Goods        Caguas
#
#   Customer Country  Customer Id Customer Segment  ...      Order State  \
# 0      Puerto Rico        20755         Consumer  ...  Java Occidental
# 1      Puerto Rico        19492         Consumer  ...         Rajastán
# 2          EE. UU.        19491         Consumer  ...         Rajastán
# 3          EE. UU.        19490      Home Office  ...       Queensland
# 4      Puerto Rico        19489        Corporate  ...       Queensland
#
#       Order Status  Order Zipcode Product Card Id  Product Category Id  \
# 0         COMPLETE            NaN            1360                   73
# 1          PENDING            NaN            1360                   73
# 2           CLOSED            NaN            1360                   73
# 3         COMPLETE            NaN            1360                   73
# 4  PENDING_PAYMENT            NaN            1360                   73
#
#    Product Name Product Price shipping date (DateOrders)   Shipping Mode  \
# 0  Smart watch         327.75             2/3/2018 22:56  Standard Class
# 1  Smart watch         327.75            1/18/2018 12:27  Standard Class
# 2  Smart watch         327.75            1/17/2018 12:06  Standard Class
# 3  Smart watch         327.75            1/16/2018 11:45  Standard Class
# 4  Smart watch         327.75            1/15/2018 11:24  Standard Class
#
#    order_date_VL
# 0     2018-01-31
# 1     2018-01-13
# 2     2018-01-13
# 3     2018-01-13
# 4     2018-01-13
#
# [5 rows x 43 columns]

# %%
sales_df.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Delivery Status', 'Late_delivery_risk', 'Category Name',
#        'Customer City', 'Customer Country', 'Customer Id', 'Customer Segment',
#        'Customer State', 'Customer Zipcode', 'Department Id',
#        'Department Name', 'Latitude', 'Longitude', 'Market', 'Order City',
#        'Order Country', 'Order Customer Id', 'order date (DateOrders)',
#        'Order Id', 'Order Item Cardprod Id', 'Order Item Discount',
#        'Order Item Discount Rate', 'Order Item Id', 'Order Item Product Price',
#        'Order Item Profit Ratio', 'Order Item Quantity', 'Sales',
#        'Order Item Total', 'Order Profit Per Order', 'Order Region',
#        'Order State', 'Order Status', 'Order Zipcode', 'Product Card Id',
#        'Product Category Id', 'Product Name', 'Product Price',
#        'shipping date (DateOrders)', 'Shipping Mode', 'order_date_VL'],
#       dtype='object')

# %% [markdown]
# Unique Order dataframe preparation

# %%
#remove rows with "Delivery Status"="Shipping canceled"
sales_df = sales_df[sales_df["Order Status"] != "CANCELED"]

# %%
#remove columns 'Days for shipping (real)', 'Late_delivery_risk'
sales_df = sales_df.drop(columns=['Days for shipping (real)', 'Late_delivery_risk'])

# %%
# create a new dataframe orders_df listing all unique "Order ID" as index with min "Type", "Days for shipment (scheduled)"
orders_df = sales_df.groupby("Order Id").agg({"Type": "min", "Days for shipment (scheduled)": "min"})
#add columns to orders_df from sales_df with 'Customer Segment', 'Department Id', 'Order Country'
orders_df = orders_df.join(sales_df.groupby("Order Id").agg({"Customer Segment": "min","Market":"min", "Order Country": "min", "Order State":"min",
                                                             "Shipping Mode":"min","Order Region":"min",
                                                             "Order Status":"min"}))
#add columns to orders_df from sales_df with sum of "Order Item Product Price", "Order Item Discount", 'Order Item Quantity',"Order Item Total"
orders_df = orders_df.join(sales_df.groupby("Order Id").agg({"Order Item Product Price": "sum", "Order Item Discount": "sum", "Order Item Quantity": "sum", "Order Item Total": "sum"}))
# add column with number of unique "Product Card Id" per "Order Id"
orders_df["Number of Products"] = sales_df.groupby("Order Id")["Product Card Id"].nunique()
#add column with number of unique "Category Name" per "Order Id"
orders_df["Number of Categories"] = sales_df.groupby("Order Id")["Category Name"].nunique()
#add column with number of unique "Department Name" per "Order Id"
orders_df["Number of Departments"] = sales_df.groupby("Order Id")["Department Name"].nunique()
orders_df.tail()
# Out:
#               Type  Days for shipment (scheduled) Customer Segment  \
# Order Id
# 77200     TRANSFER                              4         Consumer
# 77201        DEBIT                              4         Consumer
# 77202        DEBIT                              4         Consumer
# 77203      PAYMENT                              4        Corporate
# 77204         CASH                              0        Corporate
#
#                 Market Order Country      Order State   Shipping Mode  \
# Order Id
# 77200     Pacific Asia     Indonesia  Java Occidental  Standard Class
# 77201     Pacific Asia     Indonesia  Java Occidental  Standard Class
# 77202     Pacific Asia     Indonesia  Java Occidental  Standard Class
# 77203     Pacific Asia     Indonesia  Java Occidental  Standard Class
# 77204     Pacific Asia     Australia       Queensland        Same Day
#
#             Order Region     Order Status  Order Item Product Price  \
# Order Id
# 77200     Southeast Asia       PROCESSING                215.820007
# 77201     Southeast Asia         COMPLETE                215.820007
# 77202     Southeast Asia         COMPLETE                327.750000
# 77203     Southeast Asia  PENDING_PAYMENT                 11.540000
# 77204            Oceania           CLOSED                 39.750000
#
#           Order Item Discount  Order Item Quantity  Order Item Total  \
# Order Id
# 77200               53.959999                    1        161.869995
# 77201               43.160000                    1        172.660004
# 77202               13.110000                    1        314.640015
# 77203                0.630000                    1         10.910000
# 77204                4.770000                    1         34.980000
#
#           Number of Products  Number of Categories  Number of Departments
# Order Id
# 77200                      1                     1                      1
# 77201                      1                     1                      1
# 77202                      1                     1                      1
# 77203                      1                     1                      1
# 77204                      1                     1                      1

# %%
orders_df.columns
# Out:
# Index(['Type', 'Days for shipment (scheduled)', 'Customer Segment', 'Market',
#        'Order Country', 'Order State', 'Shipping Mode', 'Order Region',
#        'Order Status', 'Order Item Product Price', 'Order Item Discount',
#        'Order Item Quantity', 'Order Item Total', 'Number of Products',
#        'Number of Categories', 'Number of Departments'],
#       dtype='object')

# %%
#change column name "Order Item Total" to "order_total", change column "Order Item Product Price" to "order_original_price", "Order Item Discount" to "order_discount", "Order Item Quantity" to "no_of_items"
orders_df = orders_df.rename(columns={"Order Item Total": "order_total", "Order Item Product Price": "order_original_price", 
                                      "Order Item Discount": "order_discount", "Order Item Quantity": "no_of_items",
                                      "Number of Products": "no_of_unique_items", "Number of Categories": "no_of_unique_categories","Number of Departments": "no_of_unique_departments"})

# %%
#add column "fraud" to orders_df - mark status "SUSPECTED_FRAUD" as 1, others as 0
orders_df["fraud"] = np.where(orders_df["Order Status"] == "SUSPECTED_FRAUD", 1, 0)
#drop column "Order Status" column from orders_df
orders_df = orders_df.drop(columns=["Order Status"])
# make "fraud" an integer
orders_df["fraud"] = orders_df["fraud"].astype(int)

# %% [markdown]
# DATA CLEANING

# %%
#show data type for each column
orders_df.dtypes
# Out:
# Type                              object
# Days for shipment (scheduled)      int64
# Customer Segment                  object
# Market                            object
# Order Country                     object
# Order State                       object
# Shipping Mode                     object
# Order Region                      object
# order_original_price             float64
# order_discount                   float64
# no_of_items                        int64
# order_total                      float64
# no_of_unique_items                 int64
# no_of_unique_categories            int64
# no_of_unique_departments           int64
# fraud                              int32
# dtype: object

# %%
#save orders_df to csv file
orders_df.to_csv("Resources/orders_df.csv")

# %% [markdown]
# ################### --------------------JESS START COPYING HERE - PART 1--------###############################

# %%
#read csv file into dataframe orders_df from Resources folder
file_path = Path("Resources/orders_df.csv")
orders_df = pd.read_csv(file_path)

# %%
#dummy code categorical columns
orders_df = pd.get_dummies(orders_df, columns=["Type", "Customer Segment", "Order Country", "Order State", "Shipping Mode", "Market", "Order Region"])
orders_df.head()
# Out:
#           Days for shipment (scheduled)  order_original_price  order_discount  \
# Order Id
# 1                                     4            299.980011       60.000000
# 2                                     4            379.980011       50.600000
# 4                                     4            184.960001       78.980000
# 5                                     4            839.920029      142.789999
# 7                                     2            515.960016       54.400000
#
#           no_of_items  order_total  no_of_unique_items  \
# Order Id
# 1                   1   239.979996                   1
# 2                   7   529.380005                   3
# 4                  14   620.870014                   4
# 5                  10   987.070007                   4
# 7                   7   525.520004                   3
#
#           no_of_unique_categories  no_of_unique_departments  fraud  Type_CASH  \
# Order Id
# 1                               1                         1      0       True
# 2                               3                         3      0      False
# 4                               4                         4      0       True
# 5                               4                         2      0      False
# 7                               3                         2      0      False
#
#           ...  Order Region_South Asia  Order Region_South of  USA   \
# Order Id  ...
# 1         ...                    False                        False
# 2         ...                    False                        False
# 4         ...                    False                        False
# 5         ...                    False                        False
# 7         ...                    False                        False
#
#           Order Region_Southeast Asia  Order Region_Southern Africa  \
# Order Id
# 1                               False                         False
# 2                               False                         False
# 4                               False                         False
# 5                               False                         False
# 7                               False                         False
#
#           Order Region_Southern Europe  Order Region_US Center   \
# Order Id
# 1                                False                    False
# 2                                False                    False
# 4                                False                    False
# 5                                False                    False
# 7                                False                    False
#
#           Order Region_West Africa  Order Region_West Asia  \
# Order Id
# 1                            False                   False
# 2                            False                   False
# 4                            False                   False
# 5                            False                   False
# 7                            False                   False
#
#           Order Region_West of USA   Order Region_Western Europe
# Order Id
# 1                             False                        False
# 2                             False                        False
# 4                             False                        False
# 5                             False                        False
# 7                             False                        False
#
# [5 rows x 1300 columns]

# %% [markdown]
# ################### --------------------JESS END COPYING HERE - PART 1--------###############################

# %%
#show row count
orders_df.count()
# Out:
# Days for shipment (scheduled)    64385
# order_original_price             64385
# order_discount                   64385
# no_of_items                      64385
# order_total                      64385
#                                  ...
# Order Region_US Center           64385
# Order Region_West Africa         64385
# Order Region_West Asia           64385
# Order Region_West of USA         64385
# Order Region_Western Europe      64385
# Length: 1300, dtype: int64

# %% [markdown]
# LOGISTIC REGRESSION - FRAUD PREDICTION MODEL

# %%
# Separate the data into labels and features
# Separate the y variable, the labels
y = orders_df["fraud"]

# Separate the X variable, the features
X = orders_df.drop(columns="fraud")

# %%
# Review the y variable Series
print(f"Labels: {y[:10]}")
# Out:
# Labels: Order Id
# 1     0
# 2     0
# 4     0
# 5     0
# 7     0
# 8     0
# 9     0
# 10    0
# 11    0
# 12    0
# Name: fraud, dtype: int32

# %%
# Review the X variable DataFrame
print(f"Data: {X[:10]}")
# Out:
# Data:           Days for shipment (scheduled)  order_original_price  order_discount  \
# Order Id
# 1                                     4            299.980011       60.000000
# 2                                     4            379.980011       50.600000
# 4                                     4            184.960001       78.980000
# 5                                     4            839.920029      142.789999
# 7                                     2            515.960016       54.400000
# 8                                     4            219.960003      142.070000
# 9                                     4            499.970009       12.000000
# 10                                    4            601.940016      126.150000
# 11                                    4            299.930000       72.990000
# 12                                    4            524.950008      103.490000
#
#           no_of_items  order_total  no_of_unique_items  \
# Order Id
# 1                   1   239.979996                   1
# 2                   7   529.380005                   3
# 4                  14   620.870014                   4
# 5                  10   987.070007                   4
# 7                   7   525.520004                   3
# 8                  13   587.770004                   3
# 9                   4   587.960007                   2
# 10                  6   525.770010                   4
# 11                 15   846.800003                   4
# 12                 18  1196.380005                   5
#
#           no_of_unique_categories  no_of_unique_departments  Type_CASH  \
# Order Id
# 1                               1                         1       True
# 2                               3                         3      False
# 4                               4                         4       True
# 5                               4                         2      False
# 7                               3                         2      False
# 8                               3                         3      False
# 9                               2                         2      False
# 10                              4                         3      False
# 11                              4                         4      False
# 12                              5                         4       True
#
#           Type_DEBIT  ...  Order Region_South Asia  \
# Order Id              ...
# 1              False  ...                    False
# 2              False  ...                    False
# 4              False  ...                    False
# 5               True  ...                    False
# 7               True  ...                    False
# 8              False  ...                    False
# 9              False  ...                    False
# 10             False  ...                    False
# 11             False  ...                    False
# 12             False  ...                    False
#
#           Order Region_South of  USA   Order Region_Southeast Asia  \
# Order Id
# 1                               False                        False
# 2                               False                        False
# 4                               False                        False
# 5                               False                        False
# 7                               False                        False
# 8                               False                        False
# 9                               False                        False
# 10                              False                        False
# 11                              False                        False
# 12                              False                        False
#
#           Order Region_Southern Africa  Order Region_Southern Europe  \
# Order Id
# 1                                False                         False
# 2                                False                         False
# 4                                False                         False
# 5                                False                         False
# 7                                False                         False
# 8                                False                         False
# 9                                False                         False
# 10                               False                         False
# 11                               False                         False
# 12                               False                         False
#
#           Order Region_US Center   Order Region_West Africa  \
# Order Id
# 1                           False                     False
# 2                           False                     False
# 4                           False                     False
# 5                           False                     False
# 7                           False                     False
# 8                           False                     False
# 9                           False                     False
# 10                          False                     False
# 11                          False                     False
# 12                          False                     False
#
#           Order Region_West Asia  Order Region_West of USA   \
# Order Id
# 1                          False                      False
# 2                          False                      False
# 4                          False                      False
# 5                          False                      False
# 7                          False                      False
# 8                          False                      False
# 9                          False                      False
# 10                         False                      False
# 11                         False                      False
# 12                         False                      False
#
#           Order Region_Western Europe
# Order Id
# 1                               False
# 2                               False
# 4                               False
# 5                               False
# 7                               False
# 8                               False
# 9                               False
# 10                              False
# 11                              False
# 12                              False
#
# [10 rows x 1299 columns]

# %%
# Import the train_test_learn module
from sklearn.model_selection import train_test_split

# Split the data using train_test_split
# Assign a random_state of 1 to the function
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)
X_train.shape
# Out:
# (48288, 1299)

# %%
X_test.shape
# Out:
# (16097, 1299)

# %%
#concatenate our training data back together
train_data = pd.concat([X_train, y_train], axis=1)

# %%
#Create a logistic regression model
# Import the LogisticRegression module from SKLearn
from sklearn.linear_model import LogisticRegression

# Instantiate the Logistic Regression model with class weight to handle imbalance in the dataset
classifier = LogisticRegression(max_iter=10000)


# Fit the model using scaled training data
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
from sklearn.calibration import CalibratedClassifierCV

# Instantiate the calibrated classifier with sigmoid calibration
calibrated_clf = CalibratedClassifierCV(classifier, method='sigmoid', cv='prefit')

# Fit the calibrated classifier using the validation data (you might need to split your data again)
calibrated_clf.fit(X_train, y_train)
# Out:
# CalibratedClassifierCV(cv='prefit',
#                        estimator=LogisticRegression(max_iter=10000))

# %%
# Get calibrated probabilities
calibrated_probs = calibrated_clf.predict_proba(X_test)

# Predict labels (if needed)
calibrated_preds = calibrated_clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, log_loss

print("Accuracy: ", accuracy_score(y_test, calibrated_preds))
print("Log loss: ", log_loss(y_test, calibrated_probs))
# Out:
# Accuracy:  0.9766416102379325
# Log loss:  0.0823720268251395

# %%
# Make a prediction using the testing data with the calibrated classifier
calibrated_predictions = calibrated_clf.predict(X_test)

pd.DataFrame({"Prediction": calibrated_predictions, "Actual": y_test})
# Out:
#           Prediction  Actual
# Order Id
# 68286              0       0
# 44031              0       0
# 50283              0       0
# 27559              0       0
# 36548              0       0
# ...              ...     ...
# 47422              0       0
# 52678              0       0
# 71231              0       0
# 9763               0       0
# 48292              0       0
#
# [16097 rows x 2 columns]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# Generate a confusion matrix for the model
confusion_matrix(y_test, calibrated_predictions)
# Out:
# array([[15721,     4],
#        [  372,     0]], dtype=int64)

# %%
# Calculating the confusion matrix
cm = confusion_matrix(y_test, calibrated_predictions)
cm_df = pd.DataFrame(
    cm, index=["Legitemate [0]", "Fraud [1]"], columns=["Legitemate [0]", "Fraud [1]"]
)

# Calculating the accuracy score
acc_score = accuracy_score(y_test, calibrated_predictions)

# Display results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, calibrated_predictions))
# Out:
# Confusion Matrix
#                 Legitemate [0]  Fraud [1]
# Legitemate [0]           15721          4
# Fraud [1]                  372          0
# Accuracy Score : 0.9766416102379325
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     15725
#            1       0.00      0.00      0.00       372
#
#     accuracy                           0.98     16097
#    macro avg       0.49      0.50      0.49     16097
# weighted avg       0.95      0.98      0.97     16097

# %% [markdown]
# Terrible score for fraud recall - model was not able to identify any true fraud cases after training - the imbalanced data

# %% [markdown]
# #################------------------- JESS START COPYING HERE Part 2 ----------------------------------################

# %% [markdown]
# TESTING RANDOM FOREST MODEL - To improve accuracy and see feature importance breakdown

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

# %%
# Define features set 
X = orders_df.copy()
X.drop('fraud', axis=1, inplace=True)
X.head()
# Out:
#    Order Id  Days for shipment (scheduled)  order_original_price  \
# 0         1                              4            299.980011
# 1         2                              4            379.980011
# 2         4                              4            184.960001
# 3         5                              4            839.920029
# 4         7                              2            515.960016
#
#    order_discount  no_of_items  order_total  no_of_unique_items  \
# 0       60.000000            1   239.979996                   1
# 1       50.600000            7   529.380005                   3
# 2       78.980000           14   620.870014                   4
# 3      142.789999           10   987.070007                   4
# 4       54.400000            7   525.520004                   3
#
#    no_of_unique_categories  no_of_unique_departments  Type_CASH  ...  \
# 0                        1                         1       True  ...
# 1                        3                         3      False  ...
# 2                        4                         4       True  ...
# 3                        4                         2      False  ...
# 4                        3                         2      False  ...
#
#    Order Region_South Asia  Order Region_South of  USA   \
# 0                    False                        False
# 1                    False                        False
# 2                    False                        False
# 3                    False                        False
# 4                    False                        False
#
#    Order Region_Southeast Asia  Order Region_Southern Africa  \
# 0                        False                         False
# 1                        False                         False
# 2                        False                         False
# 3                        False                         False
# 4                        False                         False
#
#    Order Region_Southern Europe  Order Region_US Center   \
# 0                         False                    False
# 1                         False                    False
# 2                         False                    False
# 3                         False                    False
# 4                         False                    False
#
#    Order Region_West Africa  Order Region_West Asia  \
# 0                     False                   False
# 1                     False                   False
# 2                     False                   False
# 3                     False                   False
# 4                     False                   False
#
#    Order Region_West of USA   Order Region_Western Europe
# 0                      False                        False
# 1                      False                        False
# 2                      False                        False
# 3                      False                        False
# 4                      False                        False
#
# [5 rows x 1300 columns]

# %%
# Define target vector
y = orders_df["fraud"].values.reshape(-1, 1)
y[:5]
# Out:
# array([[0],
#        [0],
#        [0],
#        [0],
#        [0]])

# %%
# Splitting into Train and Test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create the StandardScaler instance
scaler = StandardScaler()

# %%
# Fit the Standard Scaler with the training data
X_scaler = scaler.fit(X_train)

# %%
# Scale the training data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the random forest classifier instance
rf_model = RandomForestClassifier(n_estimators=500, random_state=78)

# %%
# Fit the model and use .ravel()on the "y_train" data. 
rf_model = rf_model.fit(X_train_scaled, y_train.ravel())

# %%
# Making predictions using the testing data
predictions = rf_model.predict(X_test_scaled)

# %%
# Calculating the confusion matrix
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
    cm, index=["Legitemate [0]", "Fraud [1]"], columns=["Legitemate [0]", "Fraud [1]"]
)

# Calculating the accuracy score
acc_score = accuracy_score(y_test, predictions)

# %%
# Displaying results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#                 Legitemate [0]  Fraud [1]
# Legitemate [0]           15744         14
# Fraud [1]                  337          2
# Accuracy Score : 0.9781946946636019
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     15758
#            1       0.12      0.01      0.01       339
#
#     accuracy                           0.98     16097
#    macro avg       0.55      0.50      0.50     16097
# weighted avg       0.96      0.98      0.97     16097

# %%
# Get the feature importance array
importances = rf_model.feature_importances_
# List the top 10 most important features
importances_sorted = sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
importances_sorted
# Out:
# [(0.12631293806324706, 'order_total'),
#  (0.12514082872069182, 'order_discount'),
#  (0.11090539077467063, 'order_original_price'),
#  (0.07586052856900881, 'no_of_items'),
#  (0.044956687579230756, 'Type_TRANSFER'),
#  (0.03171964652016625, 'no_of_unique_departments'),
#  (0.030268778379350957, 'no_of_unique_categories'),
#  (0.02997148263191789, 'no_of_unique_items'),
#  (0.0217026694344422, 'Days for shipment (scheduled)'),
#  (0.020892859287835727, 'Customer Segment_Consumer'),
#  (0.019118506563649527, 'Customer Segment_Corporate'),
#  (0.015035435480638031, 'Customer Segment_Home Office'),
#  (0.014748726866975953, 'Shipping Mode_Standard Class'),
#  (0.014394760684020985, 'Type_DEBIT'),
#  (0.011862418879505138, 'Shipping Mode_Second Class'),
#  (0.01081253815433808, 'Shipping Mode_First Class'),
#  (0.009604863633619955, 'Type_PAYMENT'),
#  (0.005275126864943685, 'Shipping Mode_Same Day'),
#  (0.0046062390833660856, 'Type_CASH'),
#  (0.002018974024382328, 'Order State_Languedoc-Rosellón-Mediodía-Pirineos'),
#  (0.0019348188157314102, 'Order State_Isla de Francia'),
#  (0.0018996585455257117, 'Order Country_Francia'),
#  (0.001842258363992598, 'Order State_Nueva Gales del Sur'),
#  (0.0018030486548965318, 'Order State_Renania del Norte-Westfalia'),
#  (0.0017107168186841818, 'Order Country_México'),
#  (0.0016794627957878608, 'Order Region_Western Europe'),
#  (0.0016763274249566294, 'Market_Europe'),
#  (0.001646304421242637, 'Order Region_Central America'),
#  (0.001599276288801339, 'Market_LATAM'),
#  (0.0015729542795040055, 'Order Country_Alemania'),
#  (0.0015712423520115688, 'Market_Pacific Asia'),
#  (0.0015689840062733092, 'Order State_Distrito Federal'),
#  (0.0015177679293151558, 'Order State_Río de Janeiro'),
#  (0.0015045435653200238, 'Order State_California'),
#  (0.0014947771856188936, 'Order State_Queensland'),
#  (0.0014470297192457789, 'Order State_Aquitania-Lemosín-Poitou-Charentes'),
#  (0.0013783586376458488, 'Order State_Inglaterra'),
#  (0.0013364507649754832, 'Order State_Minas Gerais'),
#  (0.0013293554743814035, 'Order State_Texas'),
#  (0.0013276402293858336, 'Order State_Chihuahua'),
#  (0.0013246338104351205, 'Order Region_East of USA'),
#  (0.0013164546871376258, 'Order State_Victoria'),
#  (0.0012941065908647072, 'Order Country_Australia'),
#  (0.0012641932748680867, 'Order Region_West of USA '),
#  (0.0012607466620715062, 'Order Region_Oceania'),
#  (0.001259013429436168, 'Order Region_South America'),
#  (0.0012539861399155838, 'Order Region_Southeast Asia'),
#  (0.0012531926852963767, 'Order State_Provenza-Alpes-Costa Azul'),
#  (0.001247552277415201, 'Order Country_El Salvador'),
#  (0.0012435682753339857, 'Order Country_Reino Unido'),
#  (0.001195381385150138, 'Order Region_US Center '),
#  (0.0011874800216148122, 'Order State_San Salvador'),
#  (0.0011537795739912898, 'Order State_Nueva York'),
#  (0.001153472722437669, 'Order Region_Southern Europe'),
#  (0.0011347368374162547, 'Order State_Veracruz'),
#  (0.0011337003242880758, 'Order Country_China'),
#  (0.001125525683203002, 'Order State_Managua'),
#  (0.0011250352468436002, 'Order Country_India'),
#  (0.0011213612955873577, 'Order State_Pekín'),
#  (0.001117959900930821, 'Order Country_Brasil'),
#  (0.0011122735891672965, 'Order Region_Northern Europe'),
#  (0.0011103072220635707, 'Order Country_Indonesia'),
#  (0.001102906975522076, 'Order State_Jalisco'),
#  (0.0011015859757375214, 'Order State_Australia Occidental'),
#  (0.0010999823766527246, 'Market_USCA'),
#  (0.0010950754406613532, 'Order Country_Estados Unidos'),
#  (0.0010869357371630732, 'Order Country_Honduras'),
#  (0.0010617482915432387, 'Order Region_South of  USA '),
#  (0.0010486157779254785, 'Order State_Ohio'),
#  (0.0010422581515503752, 'Order State_Norte-Paso de Calais-Picardía'),
#  (0.0010290232668941392, 'Order State_São Paulo'),
#  (0.0010270226301120147, 'Order State_Berlín'),
#  (0.001013944649244243, 'Order State_Yakarta'),
#  (0.0010084685907281675, 'Order State_Baja California'),
#  (0.0010073424528187764, 'Order Region_Eastern Asia'),
#  (0.001007137356156149, 'Order Country_Italia'),
#  (0.0010015658387769087, 'Order State_Guizhou'),
#  (0.0010009201828600606, 'Order State_Escocia'),
#  (0.001000919050615827, 'Order State_Benguela'),
#  (0.0009988887978129213, 'Order Country_Guatemala'),
#  (0.0009963673716848263, 'Order Region_Caribbean'),
#  (0.0009907609072472299, 'Order State_Kindia'),
#  (0.0009870508263014298, 'Order State_Washington'),
#  (0.0009719786123437971, 'Order Country_Nicaragua'),
#  (0.0009672337550901286, 'Order State_Shanghái'),
#  (0.0009570626027639633, 'Order State_Borgoña-Franco Condado'),
#  (0.0009447857471026962, 'Order State_Bavaria'),
#  (0.0009375037560017087, 'Order State_Uttar Pradesh'),
#  (0.0009365862419132798, 'Order State_Ayacucho'),
#  (0.000932357369078692, 'Order State_Territorio de la Capital Australiana'),
#  (0.0009321696278294388, 'Order Country_España'),
#  (0.0009304050707214096, 'Order State_Cortés'),
#  (0.0009221852275611363, 'Order Region_South Asia'),
#  (0.0009096393726136, 'Order State_Liaoning'),
#  (0.0009094033195933067, 'Order State_Turingia'),
#  (0.0009057078124823201, 'Order State_Arizona'),
#  (0.0009054440942583779, 'Order State_Bremen'),
#  (0.0009053384113306454, 'Order State_Capital Nacional'),
#  (0.0009024574075650591, 'Order State_Países del Loira'),
#  (0.0009009507585105267, 'Order State_Java Central'),
#  (0.0009000669306945462, 'Order State_Yucatán'),
#  (0.0008854214077299239, 'Order State_Jiangsu'),
#  (0.0008802342667117312, 'Order State_Carolina del Norte'),
#  (0.0008693905074132978, 'Order State_Francisco Morazán'),
#  (0.0008691184985253773, 'Order Country_Filipinas'),
#  (0.0008637837728892386, 'Order State_Baden-Wurtemberg'),
#  (0.0008627631756442952, 'Order State_Guatemala'),
#  (0.000860490154327564, 'Order State_Valle del Cauca'),
#  (0.000849452317452757, 'Order State_Pensilvania'),
#  (0.000841704993580341, 'Order State_Maharashtra'),
#  (0.0008352564923038478, 'Market_Africa'),
#  (0.0008191125026728597, 'Order State_Punyab'),
#  (0.000818399690321246, 'Order State_Coahuila'),
#  (0.000813707692215279, 'Order Country_República Dominicana'),
#  (0.0008095143218609808, 'Order Country_Países Bajos'),
#  (0.0008063530668816807, 'Order State_Lacio'),
#  (0.0008048537799548662, 'Order State_Santo Domingo'),
#  (0.0008047905668667559, 'Order Country_Cuba'),
#  (0.000802296614839782, 'Order State_Java Occidental'),
#  (0.0008021033090253346, 'Order State_Michigan'),
#  (0.0007967163968787462, 'Order State_Zhejiang'),
#  (0.0007860867057937993, 'Order State_Canterbury'),
#  (0.0007822042423104725, 'Order State_Karnataka'),
#  (0.0007633165813205999, 'Order State_Chimaltenango'),
#  (0.0007630636683643645, 'Order State_Valenciana'),
#  (0.0007537719795888599, 'Order State_Alsacia-Champaña-Ardenas-Lorena'),
#  (0.0007429311353756471, 'Order State_Illinois'),
#  (0.0007357091112476065, 'Order Region_West Asia'),
#  (0.0007355639219554722, 'Order State_Lombardía'),
#  (0.000735232902081267, 'Order State_Schleswig-Holstein'),
#  (0.0007348673891831192, 'Order State_Jilin'),
#  (0.0007309424241335765, 'Order State_Cataluña'),
#  (0.0007295555223499788, 'Order State_Castilla y León'),
#  (0.0007165959274925524, 'Order State_Extremadura'),
#  (0.0006984463678941149, 'Order State_Chongqing'),
#  (0.0006974229361244382, 'Order State_Pernambuco'),
#  (0.0006963983020770969, 'Order State_Auvernia-Ródano-Alpes'),
#  (0.0006946383871553748, 'Order State_Oita'),
#  (0.000691790349790284, 'Order State_Kastamonu'),
#  (0.0006890503576660508, 'Order State_Anhui'),
#  (0.0006856975970721039, 'Order State_Meca'),
#  (0.0006838022644723873, 'Order State_Abruzos'),
#  (0.0006811370439309688, 'Order Country_Turquía'),
#  (0.0006678483114073106, 'Order State_Auckland'),
#  (0.0006640333791228211, 'Order State_Emilia-Romaña'),
#  (0.0006627553258697327, 'Order State_Guangdong'),
#  (0.0006565805166952777, 'Order Country_Austria'),
#  (0.00065604791298608, 'Order State_Florida'),
#  (0.0006493886154309516, 'Order State_Marañón'),
#  (0.0006472614804522988, 'Order State_Australia del Sur'),
#  (0.0006466422963141, 'Order State_Oregón'),
#  (0.0006463334638496481, 'Order State_Lagos'),
#  (0.0006453709914753367, 'Order State_Normandía'),
#  (0.0006408526495535349, 'Order State_Durango'),
#  (0.0006403770184284486, 'Order State_Meta'),
#  (0.0006403474765004034, 'Order State_Di Car'),
#  (0.0006397779009920851, 'Order Country_Argentina'),
#  (0.0006387640212807904, 'Order State_Guangxi'),
#  (0.0006352100981561392, 'Order State_Estambul'),
#  (0.0006347282476832028, 'Order State_Virginia'),
#  (0.0006346542428015814, 'Order State_Mérida'),
#  (0.000630299927650277, 'Order State_Hunan'),
#  (0.0006295822981114797, 'Order State_Diala'),
#  (0.0006287898965481944, 'Order State_Hamburgo'),
#  (0.0006224518674704078, 'Order State_Lodz'),
#  (0.0006219360746852481, 'Order State_País Vasco'),
#  (0.0006217448801168152, 'Order State_Espíritu Santo'),
#  (0.0006210097684681092, 'Order State_Atlántida'),
#  (0.0006155886485309608, 'Order State_El Cairo'),
#  (0.000615122217222156, 'Order State_Escuintla'),
#  (0.00041600742796802975, 'Order State_Delaware'),
#  (0.0004156976365767716, 'Order State_Güeldres'),
#  (0.0004132858287174679, 'Order Country_Hong Kong'),
#  (0.0004122906871583563, 'Order Country_Irak'),
#  (0.00041182912784570646, 'Order State_Friuli-Venecia Julia'),
#  (0.000408584735180298, 'Order State_Diyarbakir'),
#  (0.00040797082077482556, 'Order State_Antioquía'),
#  (0.0004055527608361221, 'Order State_Trentino-Alto Adigio'),
#  (0.00040520948346546175, 'Order State_Kentucky'),
#  (0.0004048741682124824, 'Order State_San Cristóbal'),
#  (0.0004033575448580231, 'Order State_Duarte'),
#  (0.0004017339189526702, 'Order State_Gauteng'),
#  (0.0004010628656638441, 'Order State_Mbeya'),
#  (0.00040101119237138905, 'Order State_Gran Casablanca'),
#  (0.0003997203524990795, 'Order State_Buenos Aires'),
#  (0.000399477534206467, 'Order State_Ankara'),
#  (0.0003956672365538799, 'Order State_Edo'),
#  (0.00039273971191357163, 'Order State_Kivu del Sur'),
#  (0.00039022802765200455, 'Order State_Hong Kong'),
#  (0.00038916991640406713, 'Order State_Morelos'),
#  (0.00038898363779969996, 'Order State_Alger'),
#  (0.00038826822574153613, 'Order State_Haryana'),
#  (0.0003880907085010239, 'Order State_Bagdad'),
#  (0.000384874250090556, 'Order Country_Guinea'),
#  (0.0003839280435277216, 'Order State_Galati'),
#  (0.00038370108622120137, 'Order State_Mato Grosso'),
#  (0.0003802610087432641, 'Order State_Dinamarca Meridional'),
#  (0.00037884443684064773, 'Order State_Tabuk'),
#  (0.00037703915474881865, 'Order State_Prahova'),
#  (0.0003763799579687081, 'Order State_Taiz'),
#  (0.00037463603073569125, 'Order State_Kermanshah'),
#  (0.0003732944080281856, 'Order State_Kwara'),
#  (0.0003709406480575325, 'Order State_Ceará'),
#  (0.00037069235238320367, 'Order State_Poltava'),
#  (0.00036762051481796124, 'Order State_Busan'),
#  (0.00036636338464641035, 'Order State_Henan'),
#  (0.0003662087400161904, 'Order State_Sonora'),
#  (0.0003653716418453082, 'Order State_Wellington'),
#  (0.00036483451539535554, 'Order Country_Vietnam'),
#  (0.0003627745095063701, 'Order Country_Japón'),
#  (0.0003605851325668828, 'Order State_Amazonas'),
#  (0.00035931373783948574, 'Order State_Daejeon'),
#  (0.0003564196107266427, 'Order State_Tokio'),
#  (0.0003529853186547817, 'Order State_Kanagawa'),
#  (0.00035218589860528337, 'Order State_Yunnan'),
#  (0.0003519983827281749, 'Order State_Quebec'),
#  (0.00035012736223043623, 'Order State_Pará'),
#  (0.00034876817460846593, 'Order State_Medina'),
#  (0.0003484695912279102, 'Order State_Isla de la Juventud'),
#  (0.0003475829584565258, 'Order State_Namangán'),
#  (0.00034703346692730217, 'Order State_Riau'),
#  (0.00034432198670487023, 'Order State_Holguín'),
#  (0.0003405643742425868, 'Order State_Jammu y Cachemira'),
#  (0.00034044206150014026, 'Order State_Indiana'),
#  (0.0003397891756817474, 'Order State_Braga'),
#  (0.0003389120318608627, 'Order State_México'),
#  (0.00033657978103636193, 'Order State_Riad'),
#  (0.0003352009375260524, 'Order State_Littoral'),
#  (0.000332421545747099, 'Order Region_Southern Africa'),
#  (0.00033223411124228496, 'Order State_Santa Catarina'),
#  (0.0003296314985625671, 'Order State_Caldas'),
#  (0.00032954971340481965, 'Order State_Imericia'),
#  (0.00032699569504415315, 'Order Country_Camerún'),
#  (0.0003268483982460841, 'Order Country_Canada'),
#  (0.0003248113224210206, 'Order Country_Ghana'),
#  (0.00032236152594588565, 'Order State_Septentrional'),
#  (0.00032138252131419016, 'Order Country_SudAfrica'),
#  (0.00032116647741163806, 'Order State_Kuala Lumpur'),
#  (0.0003206974746015691, 'Order State_Puducherry'),
#  (0.00031994648506929895, 'Order State_Overijssel'),
#  (0.0003190522387777899, 'Order State_Alta Austria'),
#  (0.0003189818794668408, 'Order State_Amapá'),
#  (0.0003183634256793133, 'Order State_Stiria'),
#  (0.0003172471321184608, 'Order State_Véneto'),
#  (0.00031660710928771505, 'Order State_Centro-Valle de Loira'),
#  (0.00031659962759626877, 'Order State_Shandong'),
#  (0.0003159731190325335, 'Order State_Gran Accra'),
#  (0.0003153992262590801, 'Order Country_Ucrania'),
#  (0.00031500277860814534, 'Order State_Tabasco'),
#  (0.0003142780367404271, 'Order State_Konya'),
#  (0.00031204785719578454, 'Order State_Ontario'),
#  (0.00031090885854377794, 'Order State_San Juan'),
#  (0.00031078639367782104, 'Order State_Bélgorod'),
#  (0.0003079295950801258, 'Order State_Oslo'),
#  (0.00030725245994103604, 'Order State_Groningen'),
#  (0.00030363792438716186, 'Order Country_Irán'),
#  (0.0003030580649839536, 'Order Country_Corea del Sur'),
#  (0.00030291641287908826, 'Order State_Visayas Occidental'),
#  (0.00030154228704292537, 'Order Country_Haití'),
#  (0.00030083356143203896, 'Order State_Yogyakarta'),
#  (0.0003004196826091725, 'Order State_Colón'),
#  (0.0003002637238023296, 'Order State_Dire Dawa'),
#  (0.00029991385945748886, 'Order State_Saskatchewan'),
#  (0.00029954099725852093, 'Order State_Gyeonggi'),
#  (0.0002990905973643977, 'Order Country_Etiopía'),
#  (0.00029770252643851377, 'Order State_Dublín'),
#  (0.0002969865561794547, 'Order State_Castilla-La Mancha'),
#  (0.000296577567416059, 'Order Region_Canada'),
#  (0.00029525835308896015, 'Order State_Sivas'),
#  (0.0002945964340066599, 'Order Country_Malasia'),
#  (0.00029446741389426784, 'Order State_Cuscatlán'),
#  (0.00029410891738178643, 'Order State_Wisconsin'),
#  (0.00029323575597658226, 'Order Country_Myanmar (Birmania)'),
#  (0.00029285475822400506, 'Order State_Sofía-Ciudad'),
#  (0.00029201284830796236, 'Order Country_Yemen'),
#  (0.00029113450511511756, 'Order State_Mato Grosso del Sur'),
#  (0.00029004792307549395, 'Order Country_Papúa Nueva Guinea'),
#  (0.00028960623265147597, 'Order State_Jorasán Razaví'),
#  (0.0002892824856173565, 'Order State_Córdoba'),
#  (0.00028786522544969423, 'Order Country_República Democrática del Congo'),
#  (0.00028702497355232506, 'Order State_Waikato'),
#  (0.00028461666847375255, 'Order Country_Argelia'),
#  (0.00027993597551870025, 'Order State_Guerrero'),
#  (0.0002774516572418351, 'Order State_Porto'),
#  (0.0002773553101108387, 'Order State_Holanda Meridional'),
#  (0.0002773338705857349, 'Order State_Chiapas'),
#  (0.00027697797070202454, 'Order State_Copperbelt'),
#  (0.0002768746331854057, 'Order Country_Pakistán'),
#  (0.0002762299083927162, 'Order State_Flanders Oriental'),
#  (0.00027459865058294134, 'Order State_Quintana Roo'),
#  (0.00027356649033854797, 'Order State_Adana'),
#  (0.0002727708435411682, 'Order State_Tamaulipas'),
#  (0.0002723349390393842, 'Order Region_East Africa'),
#  (0.0002712528655579872, 'Order State_Sichuan'),
#  (0.00027074627231338835, 'Order Country_Singapur'),
#  (0.0002705443133508853, 'Order State_Distrito Capital'),
#  (0.00026717681867878085, 'Order State_Pahang'),
#  (0.00026619934608635386, 'Order State_Vorónezh'),
#  (0.0002659612797165909, 'Order State_Benadir'),
#  (0.0002655527062820021, 'Order State_La Romana'),
#  (0.0002637373820943748, 'Order State_Santiago de Chile'),
#  (0.0002632959440702958, 'Order State_Mongolia Interior'),
#  (0.00026310474388675445, 'Order State_Singapur'),
#  (0.0002622780683844835, 'Order Country_Noruega'),
#  (0.00026172453061873983, 'Order State_Massachusetts'),
#  (0.0002605293262835478, 'Order State_Basilea-Ciudad'),
#  (0.0002586236579897419, 'Order Country_Zambia'),
#  (0.0002579845137675721, 'Order State_Las Tunas'),
#  (0.0002561568183283653, 'Order State_Sabah'),
#  (0.0002555967415285507, 'Order State_Rangún'),
#  (0.00025487567408548204, 'Order State_Guyarat'),
#  (0.0002543458265170653, 'Order State_Ciudad Ho Chi Minh'),
#  (0.000253936099191813, 'Order State_Piamonte'),
#  (0.00025390078137336905, 'Order State_Kinshasa'),
#  (0.00025333990027409106, 'Order State_Dayr az Zawr'),
#  (0.00025328207572240146, 'Order State_Miranda'),
#  (0.00024981512713630796, 'Order State_Grad Zagreb'),
#  (0.00024936718366093315, 'Order State_Utrecht'),
#  (0.00024888182519085256, 'Order State_Oyo'),
#  (0.0002485173394976072, 'Order State_Misisipi'),
#  (0.0002472472600402027, 'Order State_Quezaltenango'),
#  (0.0002434723260471571, 'Order State_Montserrado'),
#  (0.00024193840373922478, 'Order State_Attica'),
#  (0.00024120050668650344, 'Order Country_Trinidad y Tobago'),
#  (0.00024041945455607048, 'Order State_León'),
#  (0.00023992590418581486, 'Order State_Rajastán'),
#  (0.00023915000504255197, 'Order Country_Irlanda'),
#  (0.00023903982939474624, 'Order State_Kalimantan Oriental'),
#  (0.00023793036827489278, 'Order State_Santa Fe'),
#  (0.00023740584917117657, 'Order State_Tennessee'),
#  (0.00023646027577311698, 'Order State_Galicia'),
#  (0.00023565035087460236, 'Order Country_Marruecos'),
#  (0.000233413529239653, 'Order State_Lublin'),
#  (0.00023174029572189904, 'Order State_Meridional'),
#  (0.0002305507637332636, 'Order State_Pinar del Río'),
#  (0.00023008989962302432, 'Order Country_Bulgaria'),
#  (0.00022935536923922865, 'Order State_Dar es Salaam'),
#  (0.00022908033743492096, 'Order Country_Rumania'),
#  (0.00022697828026605005, 'Order State_Carabobo'),
#  (0.00022440971224592423, 'Order State_Orán'),
#  (2.595744825366014e-05, 'Order State_Zúrich'),
#  (2.52253893564864e-05, 'Order State_Granada'),
#  (2.5075008072540276e-05, 'Order State_Ciego de Ávila'),
#  (2.492029742030883e-05, 'Order State_Cienfuegos'),
#  (2.4572983432549836e-05, 'Order State_Hims'),
#  (2.4499026164001847e-05, 'Order State_Bursa'),
#  (2.449482516946853e-05, 'Order State_Columbia británica'),
#  (2.396897635122216e-05, 'Order State_Antalya'),
#  (2.3745220039117387e-05, 'Order State_Juzestán'),
#  (2.315230755991637e-05, 'Order State_Kansas'),
#  (2.175818713523358e-05, 'Order State_Silesia'),
#  (2.1462508152277637e-05, 'Order State_Bay of Plenty'),
#  (2.1296110940070997e-05, 'Order State_Cerdeña'),
#  (2.118124827715642e-05, 'Order State_Marche'),
#  (2.110652032216241e-05, 'Order State_Ash Sharqiyah'),
#  (2.086943353284096e-05, 'Order State_Azuay'),
#  (2.085179078281781e-05, 'Order State_Atlántico'),
#  (2.064395948679068e-05, 'Order State_Kerala'),
#  (2.0621172180182707e-05, 'Order State_San Fernando'),
#  (2.057656566254286e-05, 'Order State_Cundinamarca'),
#  (2.05006655593408e-05, 'Order State_Arbil'),
#  (2.0451274674851553e-05, 'Order State_Cork'),
#  (2.042621076798207e-05, 'Order State_Junín'),
#  (2.0324701364564747e-05, 'Order State_Nínive'),
#  (2.0019638384309193e-05, 'Order State_Mequinez-Tafilalet'),
#  (1.9933740141360557e-05, 'Order State_Santander'),
#  (1.9917041789923057e-05, 'Order State_Mayabeque'),
#  (1.9909128147941384e-05, 'Order State_Sumatra Occidental'),
#  (1.901791646092036e-05, 'Order State_Sumatra Meridional'),
#  (1.8984860123217607e-05, 'Order State_Colima'),
#  (1.859215553439526e-05, 'Order State_Anzoátegui'),
#  (1.8540417857843205e-05, 'Order State_Otago'),
#  (1.8427568558573155e-05, 'Order State_Matanzas'),
#  (1.8398517106918116e-05, 'Order State_Trengganu'),
#  (1.815321970208339e-05, 'Order State_Xinjiang Uygur'),
#  (1.7988835309675014e-05, 'Order State_Asturias'),
#  (1.7854772205453873e-05, 'Order State_Lviv'),
#  (1.7787985338506182e-05, 'Order State_Campeche'),
#  (1.760266531026172e-05, 'Order State_Donetsk'),
#  (1.734245503040301e-05, 'Order State_Annaba'),
#  (1.7280329032136403e-05, 'Order State_Brabante Flamenco'),
#  (1.7239924041451376e-05, 'Order State_Mindanao Septentrional'),
#  (1.690062282883402e-05, 'Order State_Tolima'),
#  (1.6805383351220982e-05, 'Order State_Rhode Island'),
#  (1.6337829589733683e-05, 'Order State_Negeri Sembilan'),
#  (1.6237314454078303e-05, 'Order Country_Mongolia'),
#  (1.618216385647418e-05, 'Order State_Cantabria'),
#  (1.6180445655142727e-05, 'Order State_Ulán Bator'),
#  (1.609633517363022e-05, 'Order State_Nayarit'),
#  (1.6066580316267284e-05, 'Order State_Peravia'),
#  (1.5967916636756748e-05, 'Order State_Manipur'),
#  (1.5900295415469207e-05, 'Order State_Anambra'),
#  (1.5788000409343714e-05, 'Order State_Sancti Spíritus'),
#  (1.568366167388748e-05, 'Order State_KwaZulu-Natal'),
#  (1.5467710828845153e-05, 'Order State_Tekirdag'),
#  (1.518463379128367e-05, 'Order State_Valparaíso'),
#  (1.515447126534201e-05, 'Order State_Dà Nang'),
#  (1.5128885308159013e-05, 'Order State_Drenthe'),
#  (1.5118461283077233e-05, 'Order State_Bali'),
#  (1.5019178844774847e-05, 'Order State_Kigoma'),
#  (1.5006654210063877e-05, 'Order State_Carintia'),
#  (1.4993896234339669e-05, 'Order State_Dublín del Sur'),
#  (1.4903271337040385e-05, 'Order State_Northland'),
#  (1.471368059819656e-05, 'Order State_La Vega'),
#  (1.4710612200488828e-05, 'Order State_Piura'),
#  (1.4681698911081752e-05, 'Order State_Marrakech-Tensift-Al Hauz'),
#  (1.462875634211701e-05, 'Order State_Norte de Santander'),
#  (1.4585740704315877e-05, 'Order State_Assam'),
#  (1.4403034101345177e-05, 'Order State_Kasai Occidental'),
#  (1.4400538025092129e-05, 'Order State_Al Buhayrah'),
#  (1.4333917650427667e-05, 'Order State_Zacatecas'),
#  (1.3870898332567687e-05, 'Order State_Ashanti'),
#  (1.3768391781151288e-05, 'Order State_Nzérékoré'),
#  (1.3764430695446073e-05, 'Order State_Tiflis'),
#  (1.3670857300215638e-05, 'Order State_Célebes Septentrional'),
#  (1.3654019808899502e-05, 'Order State_Nusa Tenggara Oriental'),
#  (1.357209457285242e-05, 'Order State_Flanders Occidental'),
#  (1.3479531215782533e-05, 'Order State_Cheliábinsk'),
#  (1.3306437882690308e-05, 'Order State_Teherán'),
#  (1.3305687145303908e-05, 'Order State_Shizuoka'),
#  (1.3192262681246199e-05, 'Order State_Sind'),
#  (1.317041817247921e-05, 'Order Country_Lituania'),
#  (1.2960837079503647e-05, 'Order State_Artemisa'),
#  (1.2821365791567305e-05, 'Order State_Distrito de Columbia'),
#  (1.2788481544195806e-05, 'Order State_Ceuta'),
#  (1.2225461330811896e-05, 'Order State_Katsina'),
#  (1.2220048666068283e-05, 'Order State_Manitoba'),
#  (1.1896471153551397e-05, 'Order Country_Uruguay'),
#  (1.1842134297149449e-05, 'Order Country_Mali'),
#  (1.1829473035810837e-05, 'Order State_Cluj'),
#  (1.1756178646727415e-05, 'Order State_Fez-Bulmán'),
#  (1.1727965852035591e-05, 'Order State_Odisha'),
#  (1.1680380038221758e-05, 'Order State_Tánger-Tetuán'),
#  (1.1444014133800317e-05, 'Order State_Cidade De Maputo'),
#  (1.131614211591198e-05, 'Order State_Jharkhand'),
#  (1.1307965116593353e-05, 'Order State_Artibonito'),
#  (1.1301725355521326e-05, 'Order State_Berna'),
#  (1.1123766520334139e-05, 'Order State_Cordillera'),
#  (1.0989790100964076e-05, 'Order State_Guayas'),
#  (1.0951336027642505e-05, 'Order State_Ishikawa'),
#  (1.0868487869152747e-05, 'Order Country_Ruanda'),
#  (1.078038475348719e-05, 'Order State_Kankan'),
#  (1.0686431926170107e-05, 'Order State_Piauí'),
#  (1.0648726654237799e-05, 'Order State_Erzurum'),
#  (1.0605423362806117e-05, 'Order State_Nagano'),
#  (1.0586016496550142e-05, 'Order State_Enugu'),
#  (1.6536048062590873e-06, 'Order State_Kaluga'),
#  (1.5969389340309757e-06, 'Order State_Kirsehir'),
#  (1.5872750551646455e-06, 'Order State_El Aaiún'),
#  (1.5794623220140722e-06, 'Order Country_Laos'),
#  ...]

# %% [markdown]
# Despite high accuracy, the recall for fraud cases is ridiculously low - A recall of 0.01 for fraud means the model is missing out on 99% of actual fraud cases, which is a significant risk in a real-world scenario. Assuming that data imbalance is the most likely issue, adding a resampling strategy to improve the recall

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

# %%
# Rebalance the dataset
# Use SMOTE to oversample the minority class and RandomUnderSampler to undersample the majority class
resampling = Pipeline([('SMOTE', SMOTE()), ('RandomUnderSampler', RandomUnderSampler())])
X_train_balanced, y_train_balanced = resampling.fit_resample(X_train_scaled, y_train)

# %%
# Create the random forest classifier
rf_model = RandomForestClassifier(n_estimators=500, random_state=78)
rf_model = rf_model.fit(X_train_balanced, y_train_balanced)

# %%
# Predict
predictions = rf_model.predict(X_test_scaled)

# %%
# Evaluations
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
    cm, index=["Legitemate [0]", "Fraud [1]"], columns=["Legitemate [0]", "Fraud [1]"]
)
acc_score = accuracy_score(y_test, predictions)

# %%
# Display results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#                 Legitemate [0]  Fraud [1]
# Legitemate [0]           15654        104
# Fraud [1]                  327         12
# Accuracy Score : 0.9732248245014599
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99     15758
#            1       0.10      0.04      0.05       339
#
#     accuracy                           0.97     16097
#    macro avg       0.54      0.51      0.52     16097
# weighted avg       0.96      0.97      0.97     16097

# %% [markdown]
# Testing balanced model approach to improve fraud detection

# %%
# Use class_weight='balanced' for cost-sensitive training
rf_model = RandomForestClassifier(n_estimators=500, random_state=78, class_weight='balanced')
rf_model = rf_model.fit(X_train_balanced, y_train_balanced)

# %%
# Predict probabilities
probabilities = rf_model.predict_proba(X_test_scaled)[:, 1]

# %%
# Adjust the decision threshold to increase recall
threshold = 0.3
predictions = np.where(probabilities > threshold, 1, 0)

# %%
# Evaluations
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
    cm, index=["Legitemate [0]", "Fraud [1]"], columns=["Legitemate [0]", "Fraud [1]"]
)
acc_score = accuracy_score(y_test, predictions)

# Display results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#                 Legitemate [0]  Fraud [1]
# Legitemate [0]           15416        342
# Fraud [1]                  312         27
# Accuracy Score : 0.9593713114244891
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     15758
#            1       0.07      0.08      0.08       339
#
#     accuracy                           0.96     16097
#    macro avg       0.53      0.53      0.53     16097
# weighted avg       0.96      0.96      0.96     16097

# %% [markdown]
# Increased a recall at cost of accuracy - dismall results - attempting to improve the model with XBoost to further improve fraud detection recall

# %%
import xgboost as xgb

# %%
# Convert the dataset into an optimized data structure that XGBoost supports
dtrain = xgb.DMatrix(X_train_scaled, label=y_train)
dtest = xgb.DMatrix(X_test_scaled, label=y_test)

# %%
scale_pos_weight_val = float((y_train == 0).sum() / (y_train == 1).sum())

# %%
params = {
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'max_depth': 6,
    'scale_pos_weight': scale_pos_weight_val,  # corrected this line
    'eta': 0.1
}

# %%
# Train the model
num_rounds = 300
bst = xgb.train(params, dtrain, num_rounds)

# Predict probabilities
probabilities = bst.predict(dtest)
predictions = [1 if prob > 0.5 else 0 for prob in probabilities]

# Evaluation
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
    cm, index=["Legitemate [0]", "Fraud [1]"], columns=["Legitemate [0]", "Fraud [1]"]
)
acc_score = accuracy_score(y_test, predictions)

# %%
# Display results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#                 Legitemate [0]  Fraud [1]
# Legitemate [0]           12612       3146
# Fraud [1]                   53        286
# Accuracy Score : 0.8012673168913462
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89     15758
#            1       0.08      0.84      0.15       339
#
#     accuracy                           0.80     16097
#    macro avg       0.54      0.82      0.52     16097
# weighted avg       0.98      0.80      0.87     16097

# %% [markdown]
# lassification Report:
#
# Class 0 (Legitimate Transactions):
#
# Precision: 1.00 (When the model predicted a transaction was legitimate, it was correct 100% of the time.)
# Recall: 0.80 (The model correctly identified 80% of all legitimate transactions.)
# F1-Score: 0.89 (The harmonic mean of precision and recall, giving a balanced measure for this class.)
# Class 1 (Fraudulent Transactions):
#
# Precision: 0.08 (When the model predicted a transaction was fraudulent, it was correct only 8% of the time.)
# Recall: 0.84 (The model correctly identified 84% of all fraudulent transactions, which is a good recall rate for fraud detection. However, this came at the cost of having many false positives.)
# F1-Score: 0.15 (Given the low precision and high recall, the F1-score for this class is low, indicating a potential area of improvement.)
#
# Interpretation:
# The model seems to be taking a conservative approach to fraud detection. While it has done a commendable job in identifying 84% of the fraudulent transactions (recall for Class 1), this high recall rate for fraudulent transactions has come at the expense of a large number of false positives (3,146 legitimate transactions incorrectly flagged as fraudulent). This is reflected in the very low precision (0.08) for Class 1.
#
# Such a model could be problematic in real-world scenarios, especially if there are high costs or inconveniences associated with falsely flagging a transaction as fraudulent.

# %% [markdown]
# #############################################------- JESS END COPYING HERE ----------------------------------##################

# %% [markdown]
# Failed attempt at imporveing the model by increasing the accuracy for fraud detection

# %%
#Predict probabilities
y_prob = rf_model.predict_proba(X_test_scaled)[:, 1]  # probabilities of the positive class

# %%
#Determine an optimal threshold.
from sklearn.metrics import precision_recall_curve

precisions, recalls, thresholds = precision_recall_curve(y_test, y_prob)

# %%
# Turn these into a dataframe for ease of use
thresholds_df = pd.DataFrame({'Threshold': thresholds, 'Precision': precisions[:-1], 'Recall': recalls[:-1]})

# %%
#set a minimum precision value and get the threshold for it:
min_precision = 0.2  # for example
optimal_threshold = thresholds_df[thresholds_df['Precision'] > min_precision]['Threshold'].min()

# %%
#Convert probabilities to class predictions based on the optimal threshold
y_pred_new_threshold = [1 if prob > optimal_threshold else 0 for prob in y_prob]

# %%
#ompute the confusion matrix and other metrics using y_pred_new_threshold
cm_new_threshold = confusion_matrix(y_test, y_pred_new_threshold)
print(cm_new_threshold)
print(classification_report(y_test, y_pred_new_threshold))
# Out:
# [[15756     2]
#  [  338     1]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     15758
#            1       0.33      0.00      0.01       339
#
#     accuracy                           0.98     16097
#    macro avg       0.66      0.50      0.50     16097
# weighted avg       0.97      0.98      0.97     16097

# %% [markdown]
# Increased accuracy brought the model back to extremely low recall for fraud cases.
